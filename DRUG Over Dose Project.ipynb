# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("drugoverdose.csv")
df
# Out:
#                       INDICATOR                                  PANEL  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
df.head()
# Out:
#                    INDICATOR                     PANEL  PANEL_NUM  \
# 0  Drug overdose death rates  All drug overdose deaths          0
# 1  Drug overdose death rates  All drug overdose deaths          0
# 2  Drug overdose death rates  All drug overdose deaths          0
# 3  Drug overdose death rates  All drug overdose deaths          0
# 4  Drug overdose death rates  All drug overdose deaths          0
#
#                                                 UNIT  UNIT_NUM STUB_NAME  \
# 0  Deaths per 100,000 resident population, age-ad...         1     Total
# 1  Deaths per 100,000 resident population, age-ad...         1     Total
# 2  Deaths per 100,000 resident population, age-ad...         1     Total
# 3  Deaths per 100,000 resident population, age-ad...         1     Total
# 4  Deaths per 100,000 resident population, age-ad...         1     Total
#
#    STUB_NAME_NUM   STUB_LABEL  STUB_LABEL_NUM  YEAR  YEAR_NUM       AGE  \
# ...

# %%
df.tail()
# Out:
#                       INDICATOR                                  PANEL  \
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                           UNIT  UNIT_NUM  \
# 6223          5  Deaths per 100,000 resident population, crude         2
# 6224          5  Deaths per 100,000 resident population, crude         2
# 6225          5  Deaths per 100,000 resident population, crude         2
# 6226          5  Deaths per 100,000 resident population, crude         2
# 6227          5  Deaths per 100,000 resident population, crude         2
#
#         STUB_NAME  STUB_NAME_NUM                 STUB_LABEL  STUB_LABEL_NUM  \
# ...

# %%
df.isnull().sum()
# Out:
# INDICATOR            0
# PANEL                0
# PANEL_NUM            0
# UNIT                 0
# UNIT_NUM             0
# STUB_NAME            0
# STUB_NAME_NUM        0
# STUB_LABEL           0
# STUB_LABEL_NUM       0
# YEAR                 0
# YEAR_NUM             0
# AGE                  0
# AGE_NUM              0
# ESTIMATE          1111
# FLAG              5117
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6228 entries, 0 to 6227
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDICATOR       6228 non-null   object
#  1   PANEL           6228 non-null   object
#  2   PANEL_NUM       6228 non-null   int64
#  3   UNIT            6228 non-null   object
#  4   UNIT_NUM        6228 non-null   int64
#  5   STUB_NAME       6228 non-null   object
#  6   STUB_NAME_NUM   6228 non-null   int64
#  7   STUB_LABEL      6228 non-null   object
#  8   STUB_LABEL_NUM  6228 non-null   float64
#  9   YEAR            6228 non-null   int64
#  10  YEAR_NUM        6228 non-null   int64
#  11  AGE             6228 non-null   object
#  12  AGE_NUM         6228 non-null   float64
#  13  ESTIMATE        5117 non-null   float64
#  14  FLAG            1111 non-null   object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 730.0+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(['FLAG'],axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5117 entries, 0 to 6225
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDICATOR       5117 non-null   object
#  1   PANEL           5117 non-null   object
#  2   PANEL_NUM       5117 non-null   int64
#  3   UNIT            5117 non-null   object
#  4   UNIT_NUM        5117 non-null   int64
#  5   STUB_NAME       5117 non-null   object
#  6   STUB_NAME_NUM   5117 non-null   int64
#  7   STUB_LABEL      5117 non-null   object
#  8   STUB_LABEL_NUM  5117 non-null   float64
#  9   YEAR            5117 non-null   int64
#  10  YEAR_NUM        5117 non-null   int64
#  11  AGE             5117 non-null   object
#  12  AGE_NUM         5117 non-null   float64
#  13  ESTIMATE        5117 non-null   float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 599.6+ KB

# %% [markdown]
# ### 1)count occurrences of each indicator for each year

# %%
yearly_total_indicators = df.groupby(['YEAR', 'INDICATOR']).size().reset_index(name='TOTAL')
yearly_total = yearly_total_indicators.groupby('YEAR')['TOTAL'].sum()
print(yearly_total)


plt.figure(figsize=(10,6))
yearly_total.plot(kind='bar', color='purple',width=0.6)
plt.xlabel('Year')
plt.ylabel('Total Indicators')
plt.title('Total Indicators per Year')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# YEAR
# 1999    210
# 2000    213
# 2001    222
# 2002    234
# 2003    234
# 2004    239
# 2005    247
# 2006    249
# 2007    250
# 2008    260
# 2009    261
# 2010    257
# 2011    262
# 2012    266
# 2013    263
# 2014    267
# 2015    270
# 2016    272
# 2017    279
# 2018    362
# Name: TOTAL, dtype: int64

# %% [markdown]
# ### 2)How many panels are there in the dataset?

# %%
num_panels = df['PANEL'].nunique()
panel_counts = df['PANEL'].value_counts()
print("Number of panels in the dataset:", num_panels)
print(panel_counts)
# Out:
# Number of panels in the dataset: 6
# PANEL
# All drug overdose deaths                                                         1037
# Drug overdose deaths involving any opioid                                         997
# Drug overdose deaths involving natural and semisynthetic opioids                  920
# Drug overdose deaths involving other synthetic opioids (other than methadone)     736
# Drug overdose deaths involving methadone                                          723
# Drug overdose deaths involving heroin                                             704
# Name: count, dtype: int64

# %% [markdown]
# ### 3)What is the distribution of total deaths for each unit within the 'All drug overdose deaths' panel?

# %%
unit_counts = df[df['PANEL'] == 'All drug overdose deaths']['UNIT'].value_counts()
print(unit_counts)

plt.figure(figsize=(10,6))
unit_counts.plot(kind='bar', color='green')
plt.xlabel('Unit')
plt.ylabel('Total Deaths')
plt.title('Total Deaths for Each Unit (All drug overdose deaths)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# UNIT
# Deaths per 100,000 resident population, crude           600
# Deaths per 100,000 resident population, age-adjusted    437
# Name: count, dtype: int64

# %% [markdown]
# ### 4)find out Total Deaths for Each STUB_NAME (Drug overdose deaths involving any opioid)

# %%
unit_c2 = df[df['PANEL'] == 'Drug overdose deaths involving any opioid']['STUB_NAME'].value_counts()
print(unit_c2)

plt.figure(figsize=(10,8))
unit_c2.plot(kind='bar', color='blue',width=0.6)
plt.xlabel('STUB_NAME')
plt.ylabel('Total Deaths involving any opioid')
plt.title('Total Deaths for Each STUB_NAME (Drug overdose deaths involving any opioid)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# STUB_NAME
# Sex and age                                       337
# Sex and race and Hispanic origin                  193
# Age                                               177
# Sex and race                                      154
# Sex                                                80
# Total                                              40
# Sex and race and Hispanic origin (single race)     10
# Sex and race (single race)                          6
# Name: count, dtype: int64

# %% [markdown]
# ### 5)total deaths for each STUB_NAME within the 'Drug overdose deaths involving heroin' panel?

# %%
ust = df[df['PANEL'] == 'Drug overdose deaths involving heroin']['STUB_NAME'].value_counts()
print(ust)
colors = ['green', 'lightgreen', 'salmon', 'gold', 'lightcoral', 'lightblue','brown','blue']
plt.figure(figsize=(10,8))
ust.plot(kind='bar', color=colors,width=0.6)
plt.xlabel('STUB_NAME')
plt.ylabel('Drug overdose deaths involving heroin')
plt.title('Total Deaths for Each STUB_NAME (Drug overdose deaths involving heroin)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# STUB_NAME
# Sex and age                                       205
# Sex and race and Hispanic origin                  145
# Age                                               110
# Sex and race                                      109
# Sex                                                80
# Total                                              40
# Sex and race and Hispanic origin (single race)      9
# Sex and race (single race)                          6
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['INDICATOR', 'PANEL', 'PANEL_NUM', 'UNIT', 'UNIT_NUM', 'STUB_NAME',
#        'STUB_NAME_NUM', 'STUB_LABEL', 'STUB_LABEL_NUM', 'YEAR', 'YEAR_NUM',
#        'AGE', 'AGE_NUM', 'ESTIMATE'],
#       dtype='object')

# %% [markdown]
# ### 6)What is the trend in drug overdose death rates from 1999 to 2018?

# %%
data = {
    'YEAR': [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    'ESTIMATE': [100, 120, 130, 150, 180, 200, 220, 230, 240, 250, 260, 270, 280, 290, 300, 310, 320, 330, 340, 350]
}
df1 = pd.DataFrame(data)
years = list(range(1999, 2019))
yearly_estimates = []

for year in years:
    total_deaths = df[df['YEAR'] == year]['ESTIMATE'].sum()
    yearly_estimates.append(total_deaths)

plt.figure(figsize=(10, 6))
plt.plot(years, yearly_estimates, marker='o', linestyle='-')
plt.title('Trend of Drug Overdose Death Rates (1999-2018)')
plt.xlabel('Year')
plt.ylabel('Total Drug Overdose Death Rates')
plt.grid(True)
plt.xticks(years, rotation=45) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7)drug overdose death rates vary between males and females over the years?

# %%
years_of_interest = [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

df = df[df['YEAR'].isin(years_of_interest)]
df_male = df[df['STUB_LABEL'] == 'Male']
df_female = df[df['STUB_LABEL'] == 'Female']

male_yearly = df_male.groupby('YEAR')['ESTIMATE'].mean().reset_index()
female_yearly = df_female.groupby('YEAR')['ESTIMATE'].mean().reset_index()
plt.figure(figsize=(14, 7))

plt.plot(male_yearly['YEAR'], male_yearly['ESTIMATE'], label='Males', marker='o', linestyle='-', color='blue')
plt.plot(female_yearly['YEAR'], female_yearly['ESTIMATE'], label='Females', marker='o', linestyle='-', color='pink')

plt.title('Drug Overdose Death Rates Over Selected Years by Gender')
plt.xlabel('Year')
plt.ylabel('Death Rate (Mean Estimate)') 
plt.legend()
plt.grid(True)
plt.xticks(years_of_interest, rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8)drug overdose death rates involving heroin differ between males and females?

# %%
heroin_data = df[(df['PANEL'] == 'Drug overdose deaths involving heroin') & df['STUB_LABEL'].isin(['Male', 'Female'])]
heroin_deaths_by_gender = heroin_data.groupby('STUB_LABEL')['ESTIMATE'].sum()
plt.figure(figsize=(10, 6))
heroin_deaths_by_gender.plot(kind='bar', color=['blue', 'pink'], width=0.6)
plt.xlabel('Gender')
plt.ylabel('Number of Drug Overdose Deaths Involving Heroin')
plt.title('Drug Overdose Deaths Involving Heroin by Gender')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### 9)top 5 age group has consistently shown the highest drug overdose death rates?

# %%
drug_overdose_data = df[df['INDICATOR'] == 'Drug overdose death rates']

average_death_rates_by_age = drug_overdose_data.groupby('STUB_LABEL')['ESTIMATE'].sum()
top_5_age_groups = average_death_rates_by_age.sort_values(ascending=False).head(5)

print("Top 5 age groups with the highest average drug overdose death rates:")
print(top_5_age_groups)

colors = ['pink', 'lightgreen', 'salmon', 'gold', 'lightcoral', 'lightblue']
plt.figure(figsize=(10, 6))
top_5_age_groups.plot(kind='bar', color=colors)
plt.xlabel('Age Group')
plt.ylabel('Average Death Rates')
plt.title('Top 5 age groups with the highest average drug overdose death rates')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# Top 5 age groups with the highest average drug overdose death rates:
# STUB_LABEL
# Male                 1440.4
# Male: 35-44 years    1330.8
# Male: 45-54 years    1273.1
# Male: 25-34 years    1271.7
# All persons          1095.9
# Name: ESTIMATE, dtype: float64

# %% [markdown]
# ### 10)Distribution of Estimates Across Different Units of Measurement

# %%
estimates_by_unit = df.groupby('UNIT')['ESTIMATE'].sum()
print(estimates_by_unit)

plt.figure(figsize=(12, 8))
plt.bar(estimates_by_unit.index,estimates_by_unit.values,width=0.4,color=['salmon', 'gold'],label=estimates_by_unit.index)
plt.title('Distribution of Estimates Across Different Units of Measurement')
plt.xlabel('Unit of Measurement')
plt.ylabel('Estimate')
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# UNIT
# Deaths per 100,000 resident population, age-adjusted     9735.4
# Deaths per 100,000 resident population, crude           14536.8
# Name: ESTIMATE, dtype: float64

# %% [markdown]
# ### 11)What are the top indicators by estimate, and how do they differ across different panels?

# %%
top_indicators = df.groupby(['INDICATOR', 'PANEL'])['ESTIMATE'].sum().reset_index()
top_indicators = top_indicators.sort_values(by='ESTIMATE', ascending=False).head(10)
colors = ['green', 'lightgreen', 'salmon', 'gold', 'lightcoral', 'lightblue']
plt.figure(figsize=(10, 8))
plt.barh(top_indicators['INDICATOR'] + ' (' + top_indicators['PANEL'] + ')', top_indicators['ESTIMATE'], color=colors)
plt.xlabel('Sum of Estimates')
plt.ylabel('Indicator (Panel)')
plt.title('Top Indicators by Estimate Across Different Panels')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ### 12)find out Drug Overdose Deaths by Age Group

# %%
overdose_deaths_by_age = df.groupby('AGE')['ESTIMATE'].sum().reset_index()
overdose_deaths_by_age = overdose_deaths_by_age.sort_values(by='ESTIMATE', ascending=False)
print(overdose_deaths_by_age)
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'lightcoral', 'lightblue']
plt.figure(figsize=(10, 6))
plt.bar(overdose_deaths_by_age['AGE'], overdose_deaths_by_age['ESTIMATE'], color=colors)
plt.title('Distribution of Drug Overdose Deaths by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Deaths')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
#                  AGE  ESTIMATE
# 8           All ages   11382.6
# 3        45-54 years    3102.2
# 2        35-44 years    3046.6
# 1        25-34 years    2685.5
# 4        55-64 years    1790.8
# 0        15-24 years    1088.7
# 5        65-74 years     559.9
# 7  85 years and over     319.9
# 6        75-84 years     275.9
# 9     Under 15 years      20.1
